# %%
import pandas as pd
import numpy as np
#import pivottablejs as pvt

aed = pd.read_parquet('aed_locations.parquet.gzip')
ambulances = pd.read_parquet('ambulance_locations.parquet.gzip')
cad9 = pd.read_parquet('cad9.parquet.gzip')
mug = pd.read_parquet('mug_locations.parquet.gzip')
pit = pd.read_parquet('pit_locations.parquet.gzip')
intervb1 = pd.read_parquet('interventions_bxl.parquet.gzip')
intervb2 = pd.read_parquet('interventions_bxl2.parquet.gzip')
interv1 = pd.read_parquet('interventions1.parquet.gzip')
interv2 = pd.read_parquet('interventions2.parquet.gzip')
interv3 = pd.read_parquet('interventions3.parquet.gzip')
#postal_codes = pd.read_parquet('PostalCodesBE .parquet')

# %%
#Postal Code
# postal_codes.head()
# for index, value in postal_codes.iterrows():
#     if postal_codes.at[index,'reg_name_fr'] == 'Région flamande':
#         postal_codes.at[index,'Region'] = 'Flanders'
#         postal_codes.at[index,'Province'] = postal_codes.at[index,'prov_name_nl']
#         postal_codes.at[index,'Arrondissement'] = postal_codes.at[index,'arr_name_nl']
#         postal_codes.at[index,'Municipality'] = postal_codes.at[index,'mun_name_nl']
#     elif postal_codes.at[index,'reg_name_fr'] == 'Région wallonne':
#         postal_codes.at[index,'Region'] = 'Wallonia'
#         postal_codes.at[index,'Province'] = postal_codes.at[index,'prov_name_fr']
#         postal_codes.at[index,'Arrondissement'] = postal_codes.at[index,'arr_name_fr']
#         postal_codes.at[index,'Municipality'] = postal_codes.at[index,'mun_name_fr']
#     elif postal_codes.at[index,'reg_name_fr'] == 'Région de Bruxelles-Capitale':
#         postal_codes.at[index,'Region'] = 'Brussels'
#         postal_codes.at[index,'Province'] = postal_codes.at[index,'prov_name_fr']
#         postal_codes.at[index,'Arrondissement'] = postal_codes.at[index,'arr_name_fr']
#         postal_codes.at[index,'Municipality'] = postal_codes.at[index,'mun_name_fr']
#     else:
#         postal_codes.at[index,'Region'] = 'None'
#         postal_codes.at[index,'Province'] = 'None'
#         postal_codes.at[index,'Arrondissement'] = 'None'
#         postal_codes.at[index,'Municipality'] = 'None'

# for a, b in zip(postal_codes.columns, range(0,len(postal_codes.columns))):
#                 print(f'{a}, column number {b}')
# postal_codes_subset = postal_codes.iloc[:,[2,4,5,6,7,8,26,27,28,29]]
# postal_codes_subset.head()

# %%
# AED
print(aed.head())
aed_cl=aed.copy()

for column in aed_cl.columns:
    if aed_cl[column].dtype=='object':
        aed_cl[column]=aed_cl[column].str.title().str.strip()
    else:
        aed_cl[column]=aed_cl[column]    

aed_cl.loc[aed_cl['type'].isin(['Appareil fixe','Appareil Fixe','Appareil fixe-Vast apparaat','Vast apparaat','Vast apparaat']),'type']='Fixed'
aed_cl.loc[aed_cl['type'].isin(['Appareil Mobile- Mobiel apparaat','M5066A']),'type']='Mobile'

aed_cl['postal_code']=aed_cl['postal_code'].astype('str').str.replace('.0','')

for index, value in aed.iterrows():
    if aed_cl.iloc[index, 8] in ['J', 'Ja', 'Oui', 'Oui-Ja', 'y', 'Y']:
        aed_cl.loc[index, 'public'] = 'Yes'
    elif aed_cl.iloc[index, 8] in ['Non-Nee', 'N', 'Nee']:
        aed_cl.loc[index, 'public'] = 'No'
    else:
        aed_cl.iloc[index, 8] = 'None'
        
for index, value in aed.iterrows():
    if aed_cl.iloc[index, 9] in ['J', 'Ja', 'Oui', 'Oui-Ja', 'y', 'Y', 'oui via interphone','Accessible par toute personne présente dans l inrfastructure.','Oui-Ja "Niet tijdens activiteiten van de wielervrienden"']:
        aed_cl.loc[index, 'available'] = 'Yes'
    elif aed_cl.iloc[index, 9] in ['Non-Nee', 'N', 'Nee']:
        aed_cl.loc[index, 'available'] = 'No'
    elif aed_cl.iloc[index, 9] in ['09.00 - 17.00', '9.00 - 17.00', 'Nee']:
        aed_cl.loc[index, 'available'] = '09.00 - 17.00'
    elif aed_cl.iloc[index, 9] in ['09u-12u en op aanvraag']:
        aed_cl.loc[index, 'available'] = '09.00 - 12.00'
    elif aed_cl.iloc[index, 9] in ['5h00 à 25h00', 'de 5h00 à 25h00']:
        aed_cl.loc[index, 'available'] = '05.00 - 23.59'
    elif aed_cl.iloc[index, 9] in ['8:00 - 17:00', 'N', 'Nee']:
        aed_cl.loc[index, 'available'] = '8:00 - 17:00'
    elif aed_cl.iloc[index, 9] in ['16u-23u tijdens opening sporthal']:
        aed_cl.loc[index, 'available'] = '16.00 - 23.00'
    elif aed_cl.iloc[index, 9] in ['De 5h30 à 21h30']:
        aed_cl.loc[index, 'available'] = '05.30 - 21.30'
    elif aed_cl.iloc[index, 9] in ['Dispo 24/7 - sauf samedi de 12h à dimanche 20h', 'Dispo. tout le temps sauf du samedi midi au dimanche 21h']:
        aed_cl.loc[index, 'available'] = '00.00 - 23.59'
    elif aed_cl.iloc[index, 9] in ['Heure de bureau en semaine', 'Heures de bureau', 'Horaire d ouverture de la buvette','Pendant heures d ouverture du site',
                                   'Pendant les heures de cours','Tijdens de kantooruren','Tijdens kantooruren','Tijdens openingsuren van het museum','enkel tijdens kantooruren',
                                   'enkel tijdens de kantooruren (8 - 19u)','horaire d ouverture de la pharmacie','indien de site open is, volledig toegangkelijk','kantooruren',
                                   'selon heures d ouverture d Euro-Délices','tijdens de kantooruren','tijdens de kantooruren in de week','tijdens de openingsuren','tijdens de werkuren',
                                   'tijdens onze openingsuren, zie nr. 12','tijdens openinguren sportcentrum','tijdens werkuren','zie rooster','Heures de bureau ']:
        aed_cl.loc[index, 'available'] = 'Working Opening Time'
    elif aed_cl.iloc[index, 9] in ['maandag, dinsdag, donderdag, vrijdag', 'du lundi au vendredi ']: 
        aed_cl.loc[index, 'available'] = 'During Weekdays'
    else:
        aed_cl.iloc[index, 9] = 'None'  

aed_all = pd.merge(aed_cl,postal_codes_subset, left_on = 'postal_code', right_on = 'postcode', how ='left')
for a, b in zip(aed_all.columns, range(0,len(aed_all.columns))):
                print(f'{a}, column number {b}')

aed_subset = aed_all.iloc[:,[0,1,2,3,17,18,19,20,1,4,8,9,10]]
aed_subset.head()
# Out:
#      id  type                address  number  postal_code municipality  \
# 0  13.0  None    Blvd. Fr. Roosevelt    24.0       7060.0     SOIGNIES
# 1  70.0  None        Ch. De Wégimont    76.0       4630.0      Ayeneux
# 2  71.0  None  Place Saint - Lambert     NaN       4020.0        Liège
# 3  72.0  None          Rue du Doyard     NaN       4990.0     Lierneux
# 4  73.0  None     Fond Saint Servais     NaN       4000.0        Liège
#
#   province location public available hours
# 0  Hainaut     None      Y      None  None
# 1    Liège     None   None      None  None
# 2    Liège     None   None      None  None
# 3    Liège     None   None      None  None
# 4    Liège     None   None      None  None
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 54
#      51     else:
#      52         aed_cl.iloc[index, 9] = 'None'
# ---> 54 aed_all = pd.merge(aed_cl,postal_codes_subset, left_on = 'postal_code', right_on = 'postcode', how ='left')
#      55 for a, b in zip(aed_all.columns, range(0,len(aed_all.columns))):
#      56                 print(f'{a}, column number {b}')
#
# NameError: name 'postal_codes_subset' is not defined

# %%
# ambulances
ambulances.head()
ambulances_cl=ambulances.copy()

regions = {'Brussels Hoofdstedelijk Gewest':'Brussels','Vlaams Gewest':'Flanders','Waals Gewest':'Wallonia','null':'null'}
ambulances_cl['region']=ambulances_cl['region'].map(regions)

for column in ambulances_cl.columns:
    if ambulances_cl[column].dtype=='str':
        ambulances_cl[column]=ambulances_cl[column].str.title().str.strip()
    else:
        ambulances_cl[column]=ambulances_cl[column]      
  
for index, row in ambulances_cl.iterrows():
    item = row['departure_location']
    strings = item.split()
    ambulances_cl.at[index,'departure_municipality']=item.split()[-1].title()
    for string in strings:
        if (len(string) == 4) and (string.isdigit()):
            ambulances_cl.at[index, 'departure_postalcode'] = string    

ambulances_all = pd.merge(ambulances_cl,postal_codes_subset, left_on = 'departure_postalcode', right_on = 'postcode', how ='left')
for a, b in zip(ambulances_all.columns, range(0,len(ambulances_all.columns))):
                print(f'{a}, column number {b}')

ambulances_subset = ambulances_all.iloc[:,[0,2,3,4,5,6,7,9,10,17,18,19]]
ambulances_subset.head()

# %%
# Interventions

# To show more data
pd.options.display.max_rows = 4000

# Find the name of the eventtype of interest
print(intervb1.columns)
intervb1['eventtype_trip'].head(1000)
# Out:
# Index(['mission_id', 'service_name', 'postalcode_permanence',
#        'cityname_permanence', 'streetname_permanence',
#        'housenumber_permanence', 'latitude_permanence', 'longitude_permanence',
#        'permanence_short_name', 'permanence_long_name', 'vector_type',
#        'eventtype_firstcall', 'eventLevel_firstcall', 'eventtype_trip',
#        'eventlevel_trip', 'postalcode_intervention', 'cityname_intervention',
#        'latitude_intervention', 'longitude_intervention', 't0', 't1',
#        't1confirmed', 't2', 't3', 't4', 't5', 't6', 't7', 't9',
#        'intervention_time_t1reported', 'waiting_time', 'intervention_duration',
#        'departure_time_t1reported', 'unavailable_time',
#        'name_destination_hospital', 'postalcode_destination_hospital',
#        'cityname_destination_hospital', 'streetname_destination_hospital',
#        'housenumber_destination_hospital', 'calculated_traveltime_departure_',
#        'calculated_distance_departure_to', 'calculated_traveltime_destinatio',
#        'calculated_distance_destination_', 'number_of_transported_persons',
#        'abandon_reason'],
#       dtype='object')
# 0                                          P033 - Trauma
# 1                                          P033 - Trauma
# 2                              P059 - Dizziness - Nausea
# 3                           P019 - Unconscious - syncope
# 4                                          P033 - Trauma
# 5                                          P033 - Trauma
# 6                                          P033 - Trauma
# 7                            P020 - Intoxication alcohol
# 8                        P002 - Agression - fight - rape
# 9                                          P033 - Trauma
# 10                             P074 - Palliative patient
# 11                             P074 - Palliative patient
# 12                                         P033 - Trauma
# 13                             P059 - Dizziness - Nausea
# 14                             P059 - Dizziness - Nausea
# 15                         P015 - Epilepsy - convulsions
# 16                             P021 - Intoxication drugs
# 17                          P097 - Collocation (planned)
# 18                          P097 - Collocation (planned)
# 19                        P013 - Non-traumatic back pain
# 20                        P013 - Non-traumatic back pain
# 21                             P059 - Dizziness - Nausea
# 22                          P019 - Unconscious - syncope
# 23                          P019 - Unconscious - syncope
# 24                          P019 - Unconscious - syncope
# 25                             P068 - Urogenital problem
# 26                          P019 - Unconscious - syncope
# 27                                     P011 - Chest pain
# 28                                     P011 - Chest pain
# 29                                     P011 - Chest pain
# 30                                         P033 - Trauma
# 31                   P012 - Non-traumatic abdominal pain
# 32                          P097 - Collocation (planned)
# 33                          P097 - Collocation (planned)
# 34                          P019 - Unconscious - syncope
# 35                                         P033 - Trauma
# 36                                         P033 - Trauma
# 37                          P019 - Unconscious - syncope
# 38                         P015 - Epilepsy - convulsions
# 39                         P015 - Epilepsy - convulsions
# 40                         P015 - Epilepsy - convulsions
# 41                   P012 - Non-traumatic abdominal pain
# 42                   P012 - Non-traumatic abdominal pain
# 43                   P012 - Non-traumatic abdominal pain
# 44                                     P011 - Chest pain
# 45                                         P033 - Trauma
# 46                                P026 - Unclear problem
# 47                                         P033 - Trauma
# 48                   P012 - Non-traumatic abdominal pain
# 49                               P001 - Traffic accident
# 50                               P001 - Traffic accident
# 51                                         P033 - Trauma
# 52                                         P033 - Trauma
# 53                                         P033 - Trauma
# 54                                         P033 - Trauma
# 55                                         P033 - Trauma
# 56                            P031 - Psychiatric problem
# 57                         P015 - Epilepsy - convulsions
# 58                         P015 - Epilepsy - convulsions
# 59                             P059 - Dizziness - Nausea
# 60                           P020 - Intoxication alcohol
# 61                                         P033 - Trauma
# 62                            P031 - Psychiatric problem
# 63                            P031 - Psychiatric problem
# 64                                         P033 - Trauma
# 65                            P031 - Psychiatric problem
# 66                                         P033 - Trauma
# 67                               P001 - Traffic accident
# 68                          P097 - Collocation (planned)
# 69                          P097 - Collocation (planned)
# 70                                         P033 - Trauma
# 71                            P031 - Psychiatric problem
# 72                            P031 - Psychiatric problem
# 73                     P036 - Heat stroke - solar stroke
# 74                     P036 - Heat stroke - solar stroke
# 75                     P036 - Heat stroke - solar stroke
# 76                                         P033 - Trauma
# 77                             P059 - Dizziness - Nausea
# 78                             P059 - Dizziness - Nausea
# 79                                         P033 - Trauma
# 80                             P059 - Dizziness - Nausea
# 81                                 P075 - Cancer patient
# 82                           P020 - Intoxication alcohol
# 83                               P001 - Traffic accident
# 84                           P010 - Respiratory problems
# 85                                       P009 - Diabetes
# 86                           P010 - Respiratory problems
# 87                           P010 - Respiratory problems
# 88                               P001 - Traffic accident
# 89                           P020 - Intoxication alcohol
# 90                          P019 - Unconscious - syncope
# 91                               P001 - Traffic accident
# 92                               P001 - Traffic accident
# 93                   P012 - Non-traumatic abdominal pain
# 94                                     P011 - Chest pain
# 95                                     P011 - Chest pain
# 96                              P005 - Wounded by weapon
# 97                                         P069 - Wounds
# 98                             P059 - Dizziness - Nausea
# 99                             P059 - Dizziness - Nausea
# 100                                        P033 - Trauma
# 101                          P020 - Intoxication alcohol
# 102                                        P033 - Trauma
# 103                  P012 - Non-traumatic abdominal pain
# 104                                        P033 - Trauma
# 105                         P019 - Unconscious - syncope
# 106                                        P033 - Trauma
# 107                                        P033 - Trauma
# 108                                        P033 - Trauma
# 109                                        P033 - Trauma
# 110                                    P011 - Chest pain
# 111                               P026 - Unclear problem
# 112                  P012 - Non-traumatic abdominal pain
# 113                                        P033 - Trauma
# 114                         P019 - Unconscious - syncope
# 115                                        P033 - Trauma
# 116                                        P033 - Trauma
# 117                            P074 - Palliative patient
# 118                            P074 - Palliative patient
# 119                          P020 - Intoxication alcohol
# 120                                        P033 - Trauma
# 121                            P032 - Allergic reactions
# 122                            P059 - Dizziness - Nausea
# 123                                        P004 - Stroke
# 124                                        P004 - Stroke
# 125                                        P004 - Stroke
# 126                         P019 - Unconscious - syncope
# 127                         P019 - Unconscious - syncope
# 128                         P019 - Unconscious - syncope
# 129                          P010 - Respiratory problems
# 130                          P010 - Respiratory problems
# 131                              P001 - Traffic accident
# 132                              P001 - Traffic accident
# 133                              P001 - Traffic accident
# 134    P018 - Long-term immobilisation - crushing of ...
# 135    P018 - Long-term immobilisation - crushing of ...
# 136    P039 - Cardiac problem (other than thoracic pain)
# 137    P039 - Cardiac problem (other than thoracic pain)
# 138                            P032 - Allergic reactions
# 139                            P059 - Dizziness - Nausea
# 140                            P059 - Dizziness - Nausea
# 141                                        P033 - Trauma
# 142                                        P033 - Trauma
# 143                                        P033 - Trauma
# 144                                        P033 - Trauma
# 145                                        P033 - Trauma
# 146                             FI (1.3.0) fire building
# 147                          P020 - Intoxication alcohol
# 148                          P020 - Intoxication alcohol
# 149    P039 - Cardiac problem (other than thoracic pain)
# 150                           P031 - Psychiatric problem
# 151                        P066 - Post-operative problem
# 152                        P066 - Post-operative problem
# 153                        P066 - Post-operative problem
# 154                        P066 - Post-operative problem
# 155                                        P033 - Trauma
# 156                           P031 - Psychiatric problem
# 157                            P059 - Dizziness - Nausea
# 158    P039 - Cardiac problem (other than thoracic pain)
# 159                                        P033 - Trauma
# 160                            P059 - Dizziness - Nausea
# 161                                        P033 - Trauma
# 162                          P020 - Intoxication alcohol
# 163                            P059 - Dizziness - Nausea
# 164                            P059 - Dizziness - Nausea
# 165                            P059 - Dizziness - Nausea
# 166                                        P033 - Trauma
# 167                              P061 - Limb hot or cold
# 168                            P059 - Dizziness - Nausea
# 169                                        P033 - Trauma
# 170                           P031 - Psychiatric problem
# 171                           P031 - Psychiatric problem
# 172                            P059 - Dizziness - Nausea
# 173                         P097 - Collocation (planned)
# 174                         P097 - Collocation (planned)
# 175                         P097 - Collocation (planned)
# 176                      P002 - Agression - fight - rape
# 177                        P015 - Epilepsy - convulsions
# 178                        P015 - Epilepsy - convulsions
# 179                        P015 - Epilepsy - convulsions
# 180                        P015 - Epilepsy - convulsions
# 181                                        P033 - Trauma
# 182                                        P033 - Trauma
# 183                                        P033 - Trauma
# 184                                        P033 - Trauma
# 185                                        P033 - Trauma
# 186                                        P033 - Trauma
# 187                                        P033 - Trauma
# 188                                 HG (2.1.1) gas odour
# 189                                        P033 - Trauma
# 190                                        P033 - Trauma
# 191                                        P033 - Trauma
# 192                                        P033 - Trauma
# 193                                        P033 - Trauma
# 194                                    P011 - Chest pain
# 195                                        P069 - Wounds
# 196                                    P011 - Chest pain
# 197                                    P011 - Chest pain
# 198                                    P011 - Chest pain
# 199                            P059 - Dizziness - Nausea
# 200                            P059 - Dizziness - Nausea
# 201                                        P033 - Trauma
# 202                                        P033 - Trauma
# 203                                        P033 - Trauma
# 204                                        P033 - Trauma
# 205                                P003 - Cardiac arrest
# 206                                P003 - Cardiac arrest
# 207                                P003 - Cardiac arrest
# 208                                        P004 - Stroke
# 209                                        P004 - Stroke
# 210                       P022 - Intoxication medication
# 211                           P031 - Psychiatric problem
# 212                           P031 - Psychiatric problem
# 213                  P012 - Non-traumatic abdominal pain
# 214                       P022 - Intoxication medication
# 215                                        P004 - Stroke
# 216                                        P004 - Stroke
# 217                                        P004 - Stroke
# 218                                  P034 - Skull trauma
# 219                           P031 - Psychiatric problem
# 220                  P012 - Non-traumatic abdominal pain
# 221                  P012 - Non-traumatic abdominal pain
# 222                                        P069 - Wounds
# 223                                        P069 - Wounds
# 224                  P012 - Non-traumatic abdominal pain
# 225                       P013 - Non-traumatic back pain
# 226                        P015 - Epilepsy - convulsions
# 227                                        P033 - Trauma
# 228                            P059 - Dizziness - Nausea
# 229                         P097 - Collocation (planned)
# 230                            P059 - Dizziness - Nausea
# 231                                        P033 - Trauma
# 232                      P002 - Agression - fight - rape
# 233                      P002 - Agression - fight - rape
# 234                      P002 - Agression - fight - rape
# 235                      P002 - Agression - fight - rape
# 236                          P010 - Respiratory problems
# 237                          P010 - Respiratory problems
# 238                                      P009 - Diabetes
# 239                                      P009 - Diabetes
# 240                              P061 - Limb hot or cold
# 241                               P026 - Unclear problem
# 242                                        P033 - Trauma
# 243                               P026 - Unclear problem
# 244                       P013 - Non-traumatic back pain
# 245                           P031 - Psychiatric problem
# 246                           P031 - Psychiatric problem
# 247                          P010 - Respiratory problems
# 248                          P010 - Respiratory problems
# 249                        P015 - Epilepsy - convulsions
# 250                            P032 - Allergic reactions
# 251                       P013 - Non-traumatic back pain
# 252                       P013 - Non-traumatic back pain
# 253                      P002 - Agression - fight - rape
# 254                      P002 - Agression - fight - rape
# 255                              P001 - Traffic accident
# 256                             P016 - Pregnancy - Birth
# 257                             P016 - Pregnancy - Birth
# 258                  P012 - Non-traumatic abdominal pain
# 259                          P020 - Intoxication alcohol
# 260                          P020 - Intoxication alcohol
# 261                          P020 - Intoxication alcohol
# 262    P039 - Cardiac problem (other than thoracic pain)
# 263    P039 - Cardiac problem (other than thoracic pain)
# 264    P039 - Cardiac problem (other than thoracic pain)
# 265                                        P033 - Trauma
# 266                                        P033 - Trauma
# 267                       P099 - Interhospital transport
# 268                       P099 - Interhospital transport
# 269                       P099 - Interhospital transport
# 270                               P026 - Unclear problem
# 271                          P020 - Intoxication alcohol
# 272                          P020 - Intoxication alcohol
# 273                           P031 - Psychiatric problem
# 274                             FI (1.3.0) fire building
# 275                             FI (1.3.0) fire building
# 276                  P012 - Non-traumatic abdominal pain
# 277                  P012 - Non-traumatic abdominal pain
# 278                                 HG (2.1.1) gas odour
# 279                                        P033 - Trauma
# 280                           P031 - Psychiatric problem
# 281                       P013 - Non-traumatic back pain
# 282                       P013 - Non-traumatic back pain
# 283                          P010 - Respiratory problems
# 284                                        P033 - Trauma
# 285                                        P033 - Trauma
# 286                                        P033 - Trauma
# 287                                        P033 - Trauma
# 288                                        P069 - Wounds
# 289                            P059 - Dizziness - Nausea
# 290                          P010 - Respiratory problems
# 291                          P010 - Respiratory problems
# 292                      P002 - Agression - fight - rape
# 293                          P020 - Intoxication alcohol
# 294        P008 - Patient with defibrillator - pacemaker
# 295        P008 - Patient with defibrillator - pacemaker
# 296                         P019 - Unconscious - syncope
# 297                         P019 - Unconscious - syncope
# 298                           P031 - Psychiatric problem
# 299                                        P069 - Wounds
# 300                        P017 - Non-traumatic bleeding
# 301                        P017 - Non-traumatic bleeding
# 302                                        P033 - Trauma
# 303                                    P011 - Chest pain
# 304                                    P011 - Chest pain
# 305                          P020 - Intoxication alcohol
# 306                             P005 - Wounded by weapon
# 307                          P020 - Intoxication alcohol
# 308                                        P069 - Wounds
# 309                                        P069 - Wounds
# 310                                        P033 - Trauma
# 311                                        P033 - Trauma
# 312                                        P069 - Wounds
# 313                           P031 - Psychiatric problem
# 314                  P012 - Non-traumatic abdominal pain
# 315                  P012 - Non-traumatic abdominal pain
# 316                                P003 - Cardiac arrest
# 317                                P003 - Cardiac arrest
# 318                           P031 - Psychiatric problem
# 319                           P031 - Psychiatric problem
# 320                          P010 - Respiratory problems
# 321                          P010 - Respiratory problems
# 322                                        P033 - Trauma
# 323                         P019 - Unconscious - syncope
# 324                         P019 - Unconscious - syncope
# 325                                  P034 - Skull trauma
# 326                                  P034 - Skull trauma
# 327                                      P080 - COVID-19
# 328                                        P033 - Trauma
# 329                                        P033 - Trauma
# 330    TI (3.3.3) rescue from danger to fall/jump - hard
# 331    TI (3.3.3) rescue from danger to fall/jump - hard
# 332                                                 None
# 333                           P031 - Psychiatric problem
# 334                          P010 - Respiratory problems
# 335                          P010 - Respiratory problems
# 336                          P010 - Respiratory problems
# 337                                        P033 - Trauma
# 338                                        P033 - Trauma
# 339                                        P033 - Trauma
# 340                                      P009 - Diabetes
# 341                                      P009 - Diabetes
# 342                            P059 - Dizziness - Nausea
# 343                            P059 - Dizziness - Nausea
# 344                                        P033 - Trauma
# 345                                      P009 - Diabetes
# 346                            P059 - Dizziness - Nausea
# 347                                        P033 - Trauma
# 348                                        P033 - Trauma
# 349                                        P033 - Trauma
# 350                                        P033 - Trauma
# 351                             FI (1.3.0) fire building
# 352                             FI (1.3.0) fire building
# 353                           P031 - Psychiatric problem
# 354                            P021 - Intoxication drugs
# 355                  P012 - Non-traumatic abdominal pain
# 356                  P012 - Non-traumatic abdominal pain
# 357                          P020 - Intoxication alcohol
# 358                                        P033 - Trauma
# 359    P039 - Cardiac problem (other than thoracic pain)
# 360                          P010 - Respiratory problems
# 361                          P010 - Respiratory problems
# 362                                        P033 - Trauma
# 363                  P012 - Non-traumatic abdominal pain
# 364                  P012 - Non-traumatic abdominal pain
# 365                              P001 - Traffic accident
# 366                              P001 - Traffic accident
# 367                        P066 - Post-operative problem
# 368                          P020 - Intoxication alcohol
# 369                          P020 - Intoxication alcohol
# 370                                        P033 - Trauma
# 371                                        P033 - Trauma
# 372    P039 - Cardiac problem (other than thoracic pain)
# 373    P039 - Cardiac problem (other than thoracic pain)
# 374                                        P033 - Trauma
# 375                                        P033 - Trauma
# 376                       P013 - Non-traumatic back pain
# 377                       P013 - Non-traumatic back pain
# 378                       P013 - Non-traumatic back pain
# 379                         P019 - Unconscious - syncope
# 380                               P026 - Unclear problem
# 381                               P026 - Unclear problem
# 382                         P019 - Unconscious - syncope
# 383                         P019 - Unconscious - syncope
# 384                                        P004 - Stroke
# 385                        P015 - Epilepsy - convulsions
# 386                        P015 - Epilepsy - convulsions
# 387                        P015 - Epilepsy - convulsions
# 388                  P012 - Non-traumatic abdominal pain
# 389                          P010 - Respiratory problems
# 390                          P010 - Respiratory problems
# 391                  P012 - Non-traumatic abdominal pain
# 392                           P031 - Psychiatric problem
# 393                           P031 - Psychiatric problem
# 394                           P031 - Psychiatric problem
# 395                              P001 - Traffic accident
# 396                       P099 - Interhospital transport
# 397                       P099 - Interhospital transport
# 398                         P019 - Unconscious - syncope
# 399                               P026 - Unclear problem
# 400                               P026 - Unclear problem
# 401                            P059 - Dizziness - Nausea
# 402                            P059 - Dizziness - Nausea
# 403                            P059 - Dizziness - Nausea
# 404                                        P033 - Trauma
# 405                                        P033 - Trauma
# 406                            P059 - Dizziness - Nausea
# 407                      P002 - Agression - fight - rape
# 408                           P031 - Psychiatric problem
# 409                           P031 - Psychiatric problem
# 410                           P031 - Psychiatric problem
# 411                                      P009 - Diabetes
# 412               P038 - Person does not answer the call
# 413                              P086 - vluchelingen UKR
# 414                  P012 - Non-traumatic abdominal pain
# 415                  P012 - Non-traumatic abdominal pain
# 416                  P012 - Non-traumatic abdominal pain
# 417                  P012 - Non-traumatic abdominal pain
# 418                                        P033 - Trauma
# 419                                        P033 - Trauma
# 420                                        P033 - Trauma
# 421                                        P033 - Trauma
# 422                                        P033 - Trauma
# 423                        P015 - Epilepsy - convulsions
# 424                        P015 - Epilepsy - convulsions
# 425                        P015 - Epilepsy - convulsions
# 426                        P015 - Epilepsy - convulsions
# 427                        P015 - Epilepsy - convulsions
# 428                        P015 - Epilepsy - convulsions
# 429                                P075 - Cancer patient
# 430                                P075 - Cancer patient
# 431                           P031 - Psychiatric problem
# 432                                        P033 - Trauma
# 433                            P059 - Dizziness - Nausea
# 434                            P021 - Intoxication drugs
# 435                            P021 - Intoxication drugs
# 436                           P031 - Psychiatric problem
# 437                           P031 - Psychiatric problem
# 438                            P059 - Dizziness - Nausea
# 439                                        P033 - Trauma
# 440                            P059 - Dizziness - Nausea
# 441                            P059 - Dizziness - Nausea
# 442                         P019 - Unconscious - syncope
# 443                             FI (1.3.0) fire building
# 444                             FI (1.3.0) fire building
# 445                         P019 - Unconscious - syncope
# 446                                        P033 - Trauma
# 447                                      P080 - COVID-19
# 448                               P026 - Unclear problem
# 449     P071 - Sick child < 15 years with abdominal pain
# 450                        P066 - Post-operative problem
# 451                          P010 - Respiratory problems
# 452                             P016 - Pregnancy - Birth
# 453                            P059 - Dizziness - Nausea
# 454                            P059 - Dizziness - Nausea
# 455                         P019 - Unconscious - syncope
# 456                                        P033 - Trauma
# 457                              P001 - Traffic accident
# 458                            P059 - Dizziness - Nausea
# 459                         P097 - Collocation (planned)
# 460                                        P033 - Trauma
# 461                               P026 - Unclear problem
# 462                               P026 - Unclear problem
# 463                          P010 - Respiratory problems
# 464                        P015 - Epilepsy - convulsions
# 465                        P015 - Epilepsy - convulsions
# 466                            P059 - Dizziness - Nausea
# 467                            P059 - Dizziness - Nausea
# 468                          P010 - Respiratory problems
# 469                          P010 - Respiratory problems
# 470                        P015 - Epilepsy - convulsions
# 471                        P015 - Epilepsy - convulsions
# 472                          P010 - Respiratory problems
# 473                          P010 - Respiratory problems
# 474                                P003 - Cardiac arrest
# 475                                        P033 - Trauma
# 476                       P022 - Intoxication medication
# 477                            P059 - Dizziness - Nausea
# 478                            P032 - Allergic reactions
# 479                            P032 - Allergic reactions
# 480                         P019 - Unconscious - syncope
# 481                         P097 - Collocation (planned)
# 482                         P097 - Collocation (planned)
# 483                                        P033 - Trauma
# 484                        P066 - Post-operative problem
# 485                        P066 - Post-operative problem
# 486                         P019 - Unconscious - syncope
# 487                      P002 - Agression - fight - rape
# 488                      P002 - Agression - fight - rape
# 489                            P059 - Dizziness - Nausea
# 490                            P059 - Dizziness - Nausea
# 491                           P031 - Psychiatric problem
# 492                       P098 - Collocation (unplanned)
# 493                           P031 - Psychiatric problem
# 494                           P031 - Psychiatric problem
# 495                         P019 - Unconscious - syncope
# 496                               P026 - Unclear problem
# 497                  P012 - Non-traumatic abdominal pain
# 498                                        P033 - Trauma
# 499                            P059 - Dizziness - Nausea
# 500                                        P033 - Trauma
# 501                                        P033 - Trauma
# 502                                        P069 - Wounds
# 503                          P010 - Respiratory problems
# 504                          P010 - Respiratory problems
# 505                          P010 - Respiratory problems
# 506                          P010 - Respiratory problems
# 507                         P019 - Unconscious - syncope
# 508                         P019 - Unconscious - syncope
# 509                          P010 - Respiratory problems
# 510          P029 - Obstruction of the respiratory tract
# 511          P029 - Obstruction of the respiratory tract
# 512                          P010 - Respiratory problems
# 513                          P010 - Respiratory problems
# 514                          P010 - Respiratory problems
# 515                                        P033 - Trauma
# 516                                        P033 - Trauma
# 517                      P002 - Agression - fight - rape
# 518                      P002 - Agression - fight - rape
# 519                      P002 - Agression - fight - rape
# 520                         P019 - Unconscious - syncope
# 521                              P001 - Traffic accident
# 522                                        P033 - Trauma
# 523     P071 - Sick child < 15 years with abdominal pain
# 524     P071 - Sick child < 15 years with abdominal pain
# 525                                  P034 - Skull trauma
# 526                                  P034 - Skull trauma
# 527                                        P033 - Trauma
# 528    P018 - Long-term immobilisation - crushing of ...
# 529    P018 - Long-term immobilisation - crushing of ...
# 530                          P020 - Intoxication alcohol
# 531                          P020 - Intoxication alcohol
# 532                                        P033 - Trauma
# 533                                        P033 - Trauma
# 534                                        P033 - Trauma
# 535                                        P033 - Trauma
# 536                                        P033 - Trauma
# 537                                        P033 - Trauma
# 538                                        P033 - Trauma
# 539                                        P033 - Trauma
# 540                          P010 - Respiratory problems
# 541                          P010 - Respiratory problems
# 542                        P015 - Epilepsy - convulsions
# 543                        P015 - Epilepsy - convulsions
# 544                        P015 - Epilepsy - convulsions
# 545                                        P069 - Wounds
# 546                                        P069 - Wounds
# 547                  P012 - Non-traumatic abdominal pain
# 548                              P001 - Traffic accident
# 549                                        P004 - Stroke
# 550                              P001 - Traffic accident
# 551                        P015 - Epilepsy - convulsions
# 552                        P015 - Epilepsy - convulsions
# 553                           P031 - Psychiatric problem
# 554                            P059 - Dizziness - Nausea
# 555                  P012 - Non-traumatic abdominal pain
# 556                                        P033 - Trauma
# 557                                        P033 - Trauma
# 558                                        P033 - Trauma
# 559                                        P033 - Trauma
# 560                                        P033 - Trauma
# 561                      P002 - Agression - fight - rape
# 562                          P020 - Intoxication alcohol
# 563                                        P033 - Trauma
# 564                                        P033 - Trauma
# 565                           P031 - Psychiatric problem
# 566                                        P033 - Trauma
# 567                                        P033 - Trauma
# 568                            P059 - Dizziness - Nausea
# 569                            P059 - Dizziness - Nausea
# 570                           P031 - Psychiatric problem
# 571                                        P033 - Trauma
# 572                              P001 - Traffic accident
# 573                            P068 - Urogenital problem
# 574                        P015 - Epilepsy - convulsions
# 575                        P015 - Epilepsy - convulsions
# 576                        P015 - Epilepsy - convulsions
# 577                        P015 - Epilepsy - convulsions
# 578                                        P033 - Trauma
# 579                         P019 - Unconscious - syncope
# 580    TI (3.3.3) rescue from danger to fall/jump - hard
# 581    TI (3.3.3) rescue from danger to fall/jump - hard
# 582                           P031 - Psychiatric problem
# 583                  P012 - Non-traumatic abdominal pain
# 584                         P019 - Unconscious - syncope
# 585                            P068 - Urogenital problem
# 586                         P019 - Unconscious - syncope
# 587                              P001 - Traffic accident
# 588                                        P004 - Stroke
# 589                                        P004 - Stroke
# 590                            P059 - Dizziness - Nausea
# 591                            P059 - Dizziness - Nausea
# 592                            P059 - Dizziness - Nausea
# 593                            P059 - Dizziness - Nausea
# 594                            P059 - Dizziness - Nausea
# 595                          P020 - Intoxication alcohol
# 596                       P013 - Non-traumatic back pain
# 597                                        P033 - Trauma
# 598                                        P033 - Trauma
# 599                      P002 - Agression - fight - rape
# 600                             FI (1.3.0) fire building
# 601                             FI (1.3.0) fire building
# 602                              P001 - Traffic accident
# 603                                        P033 - Trauma
# 604                         P019 - Unconscious - syncope
# 605                         P019 - Unconscious - syncope
# 606                          P010 - Respiratory problems
# 607                           P031 - Psychiatric problem
# 608                         P097 - Collocation (planned)
# 609                         P097 - Collocation (planned)
# 610               P038 - Person does not answer the call
# 611                                        P033 - Trauma
# 612                          P010 - Respiratory problems
# 613                                  P034 - Skull trauma
# 614                                  P034 - Skull trauma
# 615    P039 - Cardiac problem (other than thoracic pain)
# 616                               P026 - Unclear problem
# 617                            P059 - Dizziness - Nausea
# 618                            P059 - Dizziness - Nausea
# 619                          P010 - Respiratory problems
# 620                          P010 - Respiratory problems
# 621                          P010 - Respiratory problems
# 622                          P010 - Respiratory problems
# 623                                        P069 - Wounds
# 624                                        P069 - Wounds
# 625                                        P069 - Wounds
# 626                                        P069 - Wounds
# 627                                        P069 - Wounds
# 628                                        P069 - Wounds
# 629                                      P080 - COVID-19
# 630                            P059 - Dizziness - Nausea
# 631                            P059 - Dizziness - Nausea
# 632                                  P034 - Skull trauma
# 633                                  P034 - Skull trauma
# 634                              P001 - Traffic accident
# 635                                        P033 - Trauma
# 636                                        P033 - Trauma
# 637                                        P033 - Trauma
# 638                             FI (1.3.0) fire building
# 639                             FI (1.3.0) fire building
# 640                                        P069 - Wounds
# 641                               P026 - Unclear problem
# 642                                      P080 - COVID-19
# 643                                      P080 - COVID-19
# 644          P029 - Obstruction of the respiratory tract
# 645          P029 - Obstruction of the respiratory tract
# 646                         P097 - Collocation (planned)
# 647                         P097 - Collocation (planned)
# 648                          P020 - Intoxication alcohol
# 649                       P022 - Intoxication medication
# 650                            P068 - Urogenital problem
# 651                                    P011 - Chest pain
# 652                           P031 - Psychiatric problem
# 653                               P026 - Unclear problem
# 654                                        P033 - Trauma
# 655                           P031 - Psychiatric problem
# 656                          P010 - Respiratory problems
# 657                          P010 - Respiratory problems
# 658                                        P033 - Trauma
# 659                          P020 - Intoxication alcohol
# 660                          P020 - Intoxication alcohol
# 661                                        P033 - Trauma
# 662                                    P011 - Chest pain
# 663                                    P011 - Chest pain
# 664                          P020 - Intoxication alcohol
# 665                                        P033 - Trauma
# 666                                        P033 - Trauma
# 667                                        P033 - Trauma
# 668                          P010 - Respiratory problems
# 669                                        P033 - Trauma
# 670                                        P033 - Trauma
# 671                          P070 - Sick baby < 3 months
# 672                          P070 - Sick baby < 3 months
# 673                          P070 - Sick baby < 3 months
# 674                           P031 - Psychiatric problem
# 675                           P031 - Psychiatric problem
# 676                           P031 - Psychiatric problem
# 677               P014 - Electrocution - electrification
# 678                            P059 - Dizziness - Nausea
# 679                         P019 - Unconscious - syncope
# 680                         P019 - Unconscious - syncope
# 681                                        P033 - Trauma
# 682                          P010 - Respiratory problems
# 683                          P010 - Respiratory problems
# 684                          P010 - Respiratory problems
# 685                          P010 - Respiratory problems
# 686                            P059 - Dizziness - Nausea
# 687                            P059 - Dizziness - Nausea
# 688                  P012 - Non-traumatic abdominal pain
# 689                  P012 - Non-traumatic abdominal pain
# 690                            P059 - Dizziness - Nausea
# 691                      P002 - Agression - fight - rape
# 692                          P020 - Intoxication alcohol
# 693                                        P033 - Trauma
# 694                                        P033 - Trauma
# 695                                      P000 - ARCA DEA
# 696                                      P000 - ARCA DEA
# 697                                      P000 - ARCA DEA
# 698                                        P069 - Wounds
# 699                                        P069 - Wounds
# 700                         P019 - Unconscious - syncope
# 701                         P019 - Unconscious - syncope
# 702                                    P011 - Chest pain
# 703                                    P011 - Chest pain
# 704                          P020 - Intoxication alcohol
# 705                          P010 - Respiratory problems
# 706                          P010 - Respiratory problems
# 707                          P010 - Respiratory problems
# 708                                        P033 - Trauma
# 709                                        P033 - Trauma
# 710                            P059 - Dizziness - Nausea
# 711                            P059 - Dizziness - Nausea
# 712                                        P033 - Trauma
# 713                                        P033 - Trauma
# 714                  P012 - Non-traumatic abdominal pain
# 715                  P012 - Non-traumatic abdominal pain
# 716                      P002 - Agression - fight - rape
# 717                      P002 - Agression - fight - rape
# 718                      P002 - Agression - fight - rape
# 719                            P059 - Dizziness - Nausea
# 720                            P059 - Dizziness - Nausea
# 721                             P016 - Pregnancy - Birth
# 722                        P015 - Epilepsy - convulsions
# 723                        P015 - Epilepsy - convulsions
# 724                         P097 - Collocation (planned)
# 725                         P097 - Collocation (planned)
# 726                         P097 - Collocation (planned)
# 727                         P097 - Collocation (planned)
# 728                         P019 - Unconscious - syncope
# 729                                  P034 - Skull trauma
# 730                                  P034 - Skull trauma
# 731                          P010 - Respiratory problems
# 732                          P010 - Respiratory problems
# 733                          P010 - Respiratory problems
# 734                                    P011 - Chest pain
# 735                                    P011 - Chest pain
# 736                                    P011 - Chest pain
# 737                                    P011 - Chest pain
# 738                          P010 - Respiratory problems
# 739                          P010 - Respiratory problems
# 740                  P012 - Non-traumatic abdominal pain
# 741                  P012 - Non-traumatic abdominal pain
# 742                                        P033 - Trauma
# 743                          P010 - Respiratory problems
# 744                          P010 - Respiratory problems
# 745                           P031 - Psychiatric problem
# 746                           P031 - Psychiatric problem
# 747                                      P009 - Diabetes
# 748                                      P009 - Diabetes
# 749                                      P009 - Diabetes
# 750                                      P080 - COVID-19
# 751                          P020 - Intoxication alcohol
# 752                                        P033 - Trauma
# 753                        P015 - Epilepsy - convulsions
# 754                        P015 - Epilepsy - convulsions
# 755                        P015 - Epilepsy - convulsions
# 756                           P031 - Psychiatric problem
# 757                           P031 - Psychiatric problem
# 758                  P012 - Non-traumatic abdominal pain
# 759                         P019 - Unconscious - syncope
# 760                          P010 - Respiratory problems
# 761                          P020 - Intoxication alcohol
# 762                  P012 - Non-traumatic abdominal pain
# 763                              P001 - Traffic accident
# 764                         P097 - Collocation (planned)
# 765                         P019 - Unconscious - syncope
# 766                           P031 - Psychiatric problem
# 767                                      P009 - Diabetes
# 768                  P012 - Non-traumatic abdominal pain
# 769                           P031 - Psychiatric problem
# 770                       P013 - Non-traumatic back pain
# 771                          P020 - Intoxication alcohol
# 772                          P020 - Intoxication alcohol
# 773                                        P004 - Stroke
# 774                                        P004 - Stroke
# 775                       P013 - Non-traumatic back pain
# 776                       P013 - Non-traumatic back pain
# 777                            P059 - Dizziness - Nausea
# 778                          P020 - Intoxication alcohol
# 779                          P020 - Intoxication alcohol
# 780                            P059 - Dizziness - Nausea
# 781                  P012 - Non-traumatic abdominal pain
# 782                  P012 - Non-traumatic abdominal pain
# 783                                        P033 - Trauma
# 784                                        P033 - Trauma
# 785                           P031 - Psychiatric problem
# 786                                        P033 - Trauma
# 787                          P010 - Respiratory problems
# 788                        P015 - Epilepsy - convulsions
# 789                                        P004 - Stroke
# 790                                        P004 - Stroke
# 791                                        P004 - Stroke
# 792                      P002 - Agression - fight - rape
# 793                          P010 - Respiratory problems
# 794                            P021 - Intoxication drugs
# 795                          P020 - Intoxication alcohol
# 796                                        P069 - Wounds
# 797                                        P033 - Trauma
# 798                           P031 - Psychiatric problem
# 799                          P010 - Respiratory problems
# 800                             P016 - Pregnancy - Birth
# 801                            P059 - Dizziness - Nausea
# 802                                        P004 - Stroke
# 803                            P068 - Urogenital problem
# 804                            P059 - Dizziness - Nausea
# 805                            P059 - Dizziness - Nausea
# 806                                        P069 - Wounds
# 807                                        P069 - Wounds
# 808                              P001 - Traffic accident
# 809                  P012 - Non-traumatic abdominal pain
# 810                  P012 - Non-traumatic abdominal pain
# 811                  P012 - Non-traumatic abdominal pain
# 812                                        P033 - Trauma
# 813                         P019 - Unconscious - syncope
# 814                         P019 - Unconscious - syncope
# 815                         P019 - Unconscious - syncope
# 816                       P013 - Non-traumatic back pain
# 817                       P013 - Non-traumatic back pain
# 818                                        P033 - Trauma
# 819                                        P033 - Trauma
# 820                                        P033 - Trauma
# 821                            P059 - Dizziness - Nausea
# 822                            P059 - Dizziness - Nausea
# 823                            P059 - Dizziness - Nausea
# 824                            P059 - Dizziness - Nausea
# 825                  P012 - Non-traumatic abdominal pain
# 826                          P010 - Respiratory problems
# 827                                        P033 - Trauma
# 828                           P031 - Psychiatric problem
# 829                        P015 - Epilepsy - convulsions
# 830                            P059 - Dizziness - Nausea
# 831                       P022 - Intoxication medication
# 832                          P020 - Intoxication alcohol
# 833                          P020 - Intoxication alcohol
# 834                                        P033 - Trauma
# 835                                        P033 - Trauma
# 836                                        P033 - Trauma
# 837                             P005 - Wounded by weapon
# 838                  P012 - Non-traumatic abdominal pain
# 839    P018 - Long-term immobilisation - crushing of ...
# 840    P018 - Long-term immobilisation - crushing of ...
# 841                      P002 - Agression - fight - rape
# 842    P039 - Cardiac problem (other than thoracic pain)
# 843    P039 - Cardiac problem (other than thoracic pain)
# 844    P039 - Cardiac problem (other than thoracic pain)
# 845                              P001 - Traffic accident
# 846                  P012 - Non-traumatic abdominal pain
# 847                            P059 - Dizziness - Nausea
# 848                            P059 - Dizziness - Nausea
# 849                                        P033 - Trauma
# 850                              P001 - Traffic accident
# 851                                        P033 - Trauma
# 852                                        P033 - Trauma
# 853                           P031 - Psychiatric problem
# 854                             P005 - Wounded by weapon
# 855                               P026 - Unclear problem
# 856                                        P033 - Trauma
# 857                                        P033 - Trauma
# 858                          P010 - Respiratory problems
# 859                            P059 - Dizziness - Nausea
# 860                            P059 - Dizziness - Nausea
# 861                            P059 - Dizziness - Nausea
# 862                                      P009 - Diabetes
# 863                        P017 - Non-traumatic bleeding
# 864    P039 - Cardiac problem (other than thoracic pain)
# 865                                        P033 - Trauma
# 866                                        P033 - Trauma
# 867                                        P033 - Trauma
# 868                             P016 - Pregnancy - Birth
# 869                             P016 - Pregnancy - Birth
# 870                             P016 - Pregnancy - Birth
# 871                                        P033 - Trauma
# 872                                        P033 - Trauma
# 873                                        P033 - Trauma
# 874                                        P033 - Trauma
# 875                                        P033 - Trauma
# 876                                        P033 - Trauma
# 877    P018 - Long-term immobilisation - crushing of ...
# 878                                        P033 - Trauma
# 879                                        P033 - Trauma
# 880                                        P033 - Trauma
# 881                                        P033 - Trauma
# 882               P038 - Person does not answer the call
# 883               P038 - Person does not answer the call
# 884                       P013 - Non-traumatic back pain
# 885                       P013 - Non-traumatic back pain
# 886    P039 - Cardiac problem (other than thoracic pain)
# 887                                         P006 - Burns
# 888                                         P006 - Burns
# 889                                P075 - Cancer patient
# 890                                    P011 - Chest pain
# 891                                        P033 - Trauma
# 892                                      P000 - ARCA DEA
# 893                                      P000 - ARCA DEA
# 894                            P068 - Urogenital problem
# 895                                        P033 - Trauma
# 896                                        P033 - Trauma
# 897                         P019 - Unconscious - syncope
# 898                  P012 - Non-traumatic abdominal pain
# 899                            P059 - Dizziness - Nausea
# 900     P071 - Sick child < 15 years with abdominal pain
# 901     P071 - Sick child < 15 years with abdominal pain
# 902    P039 - Cardiac problem (other than thoracic pain)
# 903                            P059 - Dizziness - Nausea
# 904                            P059 - Dizziness - Nausea
# 905                               P026 - Unclear problem
# 906                  P012 - Non-traumatic abdominal pain
# 907                          P010 - Respiratory problems
# 908                            P059 - Dizziness - Nausea
# 909                                        P033 - Trauma
# 910    P039 - Cardiac problem (other than thoracic pain)
# 911                       P013 - Non-traumatic back pain
# 912                             P016 - Pregnancy - Birth
# 913                             P016 - Pregnancy - Birth
# 914                             P016 - Pregnancy - Birth
# 915                            P059 - Dizziness - Nausea
# 916                            P059 - Dizziness - Nausea
# 917                            P059 - Dizziness - Nausea
# 918                            P059 - Dizziness - Nausea
# 919                                        P069 - Wounds
# 920    P039 - Cardiac problem (other than thoracic pain)
# 921    P039 - Cardiac problem (other than thoracic pain)
# 922    P039 - Cardiac problem (other than thoracic pain)
# 923                               P026 - Unclear problem
# 924                                        P033 - Trauma
# 925                               P026 - Unclear problem
# 926                                        P033 - Trauma
# 927                                        P033 - Trauma
# 928                         P097 - Collocation (planned)
# 929                                        P033 - Trauma
# 930                        P015 - Epilepsy - convulsions
# 931    P039 - Cardiac problem (other than thoracic pain)
# 932    P039 - Cardiac problem (other than thoracic pain)
# 933                               P026 - Unclear problem
# 934    P039 - Cardiac problem (other than thoracic pain)
# 935                  P012 - Non-traumatic abdominal pain
# 936                              P061 - Limb hot or cold
# 937                                        P004 - Stroke
# 938                                        P004 - Stroke
# 939                                        P033 - Trauma
# 940                               P026 - Unclear problem
# 941                         P019 - Unconscious - syncope
# 942    P039 - Cardiac problem (other than thoracic pain)
# 943                       P099 - Interhospital transport
# 944                                  P034 - Skull trauma
# 945                       P099 - Interhospital transport
# 946                       P099 - Interhospital transport
# 947                                      P009 - Diabetes
# 948                                      P009 - Diabetes
# 949                          P010 - Respiratory problems
# 950                      P002 - Agression - fight - rape
# 951    P018 - Long-term immobilisation - crushing of ...
# 952                                        P033 - Trauma
# 953                         P097 - Collocation (planned)
# 954                       P099 - Interhospital transport
# 955                       P099 - Interhospital transport
# 956                                        P033 - Trauma
# 957                                        P033 - Trauma
# 958                       P013 - Non-traumatic back pain
# 959                              P001 - Traffic accident
# 960                               P026 - Unclear problem
# 961                                        P033 - Trauma
# 962                                        P033 - Trauma
# 963                  P012 - Non-traumatic abdominal pain
# 964    P039 - Cardiac problem (other than thoracic pain)
# 965    P039 - Cardiac problem (other than thoracic pain)
# 966    P039 - Cardiac problem (other than thoracic pain)
# 967                          P020 - Intoxication alcohol
# 968                        P017 - Non-traumatic bleeding
# 969                        P017 - Non-traumatic bleeding
# 970                                        P033 - Trauma
# 971                                        P033 - Trauma
# 972                          P020 - Intoxication alcohol
# 973                         P097 - Collocation (planned)
# 974                         P097 - Collocation (planned)
# 975                                        P033 - Trauma
# 976                                        P033 - Trauma
# 977                            P059 - Dizziness - Nausea
# 978                         P019 - Unconscious - syncope
# 979                             P005 - Wounded by weapon
# 980                             P005 - Wounded by weapon
# 981                             P005 - Wounded by weapon
# 982                             P005 - Wounded by weapon
# 983                                  P034 - Skull trauma
# 984                                        P033 - Trauma
# 985                                        P033 - Trauma
# 986                      P002 - Agression - fight - rape
# 987                      P002 - Agression - fight - rape
# 988                                P003 - Cardiac arrest
# 989                                P003 - Cardiac arrest
# 990                                    P011 - Chest pain
# 991                                    P011 - Chest pain
# 992                         P097 - Collocation (planned)
# 993                         P097 - Collocation (planned)
# 994                  P012 - Non-traumatic abdominal pain
# 995                            P059 - Dizziness - Nausea
# 996                                        P033 - Trauma
# 997                        P015 - Epilepsy - convulsions
# 998                        P015 - Epilepsy - convulsions
# 999                                        P004 - Stroke
# Name: eventtype_trip, dtype: object

# %%
# Keep only P003 interventions 
# P003 - Cardiac arrest
# P039 - Cardiac problem (other than thoracic pain) not taken into account
# Because it doesn't require DEA/AED

i = intervb1[intervb1['eventtype_trip'] != ('P003 - Cardiac arrest')].index
intervb1P003 = intervb1.drop(i)
intervb1P003['eventtype_trip'].head(5)
# Out:
# 205    P003 - Cardiac arrest
# 206    P003 - Cardiac arrest
# 207    P003 - Cardiac arrest
# 316    P003 - Cardiac arrest
# 317    P003 - Cardiac arrest
# Name: eventtype_trip, dtype: object

# %%
print(intervb2.columns)
intervb2['EventType and EventLevel'].head(1000)
# P003  N01 - HARTSTILSTAND - DOOD - OVERLEDEN
# P039 N05 - CARDIAAL PROBLEEM (ANDERE DAN PIJN AAN DE BORST)

# Keep only P003 interventions
i = intervb2[intervb2['EventType and EventLevel'] != ('P003  N01 - HARTSTILSTAND - DOOD - OVERLEDEN')].index
intervb2P003 = intervb2.drop(i)
intervb2P003['EventType and EventLevel'].head(5)
# Out:
# Index(['Mission ID', 'T0', 'Cityname Intervention', 'Longitude intervention',
#        'Latitude intervention', 'description_nl', 'ic_description_nl',
#        'EventType and EventLevel', 'creationtime',
#        'Number of transported persons', 'Permanence long name NL',
#        'Permanence long name FR', 'Permanence short name NL',
#        'Permanence short name FR', 'Service Name NL', 'Service Name FR',
#        'Cityname Permanence', 'Streetname Permanence',
#        'Housenumber Permanence', 'Latitude Permanence', 'Longitude Permanence',
#        'Vector type NL', 'Vector type FR', 'Name destination hospital',
#        'Cityname destination hospital', 'Streetname destination hospital',
#        'Housenumber destination hospital', 'Abandon reason NL',
#        'Abandon reason FR', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7'],
#       dtype='object')
# 808     P003  N01 - HARTSTILSTAND - DOOD - OVERLEDEN
# 809     P003  N01 - HARTSTILSTAND - DOOD - OVERLEDEN
# 1074    P003  N01 - HARTSTILSTAND - DOOD - OVERLEDEN
# 1075    P003  N01 - HARTSTILSTAND - DOOD - OVERLEDEN
# 1622    P003  N01 - HARTSTILSTAND - DOOD - OVERLEDEN
# Name: EventType and EventLevel, dtype: object

# %%
# Change/standardize columns name
# print(intervb1P003.columns)
# print(intervb2P003.columns)
# 'Mission ID','Latitude permanence', 'Longitude permanence','Latitude intervention', 'Longitude intervention','T0', 'T1', 'T2', 'T3'
intervb1P003.rename(columns={'mission_id':'Mission ID','latitude_permanence':'Latitude permanence',"longitude_permanence":"Longitude permanence",
                             "longitude_intervention":"Longitude intervention","latitude_intervention":"Latitude intervention",
                             "t0":"T0","t1":"T1","t2":"T2","t3":"T3"},inplace=True)
intervb2P003.rename(columns={'Mission ID':'Mission ID','Latitude Permanence':'Latitude permanence',"Longitude Permanence":"Longitude permanence",
                             "Longitude intervention":"Longitude intervention","Latitude intervention":"Latitude intervention",
                             "t0":"T0","t1":"T1","t2":"T2","t3":"T3"},inplace=True)
print(intervb1P003.columns)
print(intervb2P003.columns)
# Out:
# Index(['Mission ID', 'service_name', 'postalcode_permanence',
#        'cityname_permanence', 'streetname_permanence',
#        'housenumber_permanence', 'Latitude permanence', 'Longitude permanence',
#        'permanence_short_name', 'permanence_long_name', 'vector_type',
#        'eventtype_firstcall', 'eventLevel_firstcall', 'eventtype_trip',
#        'eventlevel_trip', 'postalcode_intervention', 'cityname_intervention',
#        'Latitude intervention', 'Longitude intervention', 'T0', 'T1',
#        't1confirmed', 'T2', 'T3', 't4', 't5', 't6', 't7', 't9',
#        'intervention_time_t1reported', 'waiting_time', 'intervention_duration',
#        'departure_time_t1reported', 'unavailable_time',
#        'name_destination_hospital', 'postalcode_destination_hospital',
#        'cityname_destination_hospital', 'streetname_destination_hospital',
#        'housenumber_destination_hospital', 'calculated_traveltime_departure_',
#        'calculated_distance_departure_to', 'calculated_traveltime_destinatio',
#        'calculated_distance_destination_', 'number_of_transported_persons',
#        'abandon_reason'],
#       dtype='object')
# Index(['Mission ID', 'T0', 'Cityname Intervention', 'Longitude intervention',
#        'Latitude intervention', 'description_nl', 'ic_description_nl',
#        'EventType and EventLevel', 'creationtime',
#        'Number of transported persons', 'Permanence long name NL',
#        'Permanence long name FR', 'Permanence short name NL',
#        'Permanence short name FR', 'Service Name NL', 'Service Name FR',
#        'Cityname Permanence', 'Streetname Permanence',
#        'Housenumber Permanence', 'Latitude permanence', 'Longitude permanence',
#        'Vector type NL', 'Vector type FR', 'Name destination hospital',
#        'Cityname destination hospital', 'Streetname destination hospital',
#        'Housenumber destination hospital', 'Abandon reason NL',
#        'Abandon reason FR', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7'],
#       dtype='object')

# %%
from datetime import datetime, timedelta, date

intervb1P003_subset= intervb1P003[['Mission ID','Latitude permanence', 'Longitude permanence','Latitude intervention', 'Longitude intervention','T0', 'T1', 'T2', 'T3']]
intervb2P003_subset= intervb2P003[['Mission ID','Latitude permanence', 'Longitude permanence','Latitude intervention', 'Longitude intervention','T0', 'T1', 'T2', 'T3']]

def time_interv1(date_string):
    try:
        date_str,other = date_string.split(".")
        useless,UTCoffset=other.split(" ")
        UTCoffset = UTCoffset.replace(':','')
        date_value = datetime.strptime(date_str, "%Y-%m-%d %H:%M:%S")
        if UTCoffset[0] == '+':
            date_value = date_value + timedelta(hours=int(UTCoffset[1:3]))
        else:
            date_value = date_value - timedelta(hours=int(UTCoffset[1:3]))
    except:
          date_value=date(1, 1, 1)#Define default value to remove, other function didn't work
    return date_value

def time_interv2(date_string):
        try:
            date_value=datetime.strptime(date_string, "%d%b%y:%H:%M:%S")
        except:
            date_value=date(1, 1, 1)#Define default value to remove, other function didn't work
        return date_value 

t_lst = ['T0','T1','T2','T3']
for t in (t_lst):
    intervb1P003_subset[t]=intervb1P003_subset.apply(lambda x: time_interv1(x[t]), axis=1)
    i1 = intervb1P003_subset[intervb1P003_subset[t] == date(1, 1, 1)].index
    intervb1P003_subset = intervb1P003_subset.drop(i1)
    intervb2P003_subset[t]=intervb2P003_subset.apply(lambda x: time_interv2(x[t]), axis=1)
    i2 = intervb2P003_subset[intervb2P003_subset[t] == date(1, 1, 1)].index
    intervb2P003_subset = intervb2P003_subset.drop(i2)    

intervb2P003_subset.head(10)
# Out:
# C:\Users\Ramy\AppData\Local\Temp\ipykernel_15440\1250143870.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intervb1P003_subset[t]=intervb1P003_subset.apply(lambda x: time_interv1(x[t]), axis=1)
# C:\Users\Ramy\AppData\Local\Temp\ipykernel_15440\1250143870.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intervb2P003_subset[t]=intervb2P003_subset.apply(lambda x: time_interv2(x[t]), axis=1)
#        Mission ID  Latitude permanence  Longitude permanence  \
# 1074  20221540196         5.083563e+10          4.347475e+10
# 1623  20221550234         5.088720e+10          4.310674e+10
# 2074  20221560240         5.088720e+10          4.310674e+10
# 2698  20221580127         5.083266e+09          4.311889e+10
# 3425  20221600077         5.088720e+10          4.310674e+10
# 3664  20221600314         5.085393e+10          4.359311e+10
# 3665  20221600314         5.083266e+09          4.311889e+10
# 6342  20221670067         5.088720e+10          4.310674e+10
# 8033  20221700355         5.085217e+10          4.460210e+10
# 8034  20221700355         5.085277e+10          4.453082e+10
#
#       Latitude intervention  Longitude intervention                  T0  \
# 1074           5.084320e+10            4.343397e+10 2022-06-03 11:46:26
# 1623           5.088146e+09            4.347456e+10 2022-06-04 16:11:01
# 2074           5.087553e+10            4.325066e+10 2022-06-05 14:11:53
# 2698           5.084330e+08            4.276438e+10 2022-06-07 10:39:51
# 3425           5.086833e+10            4.309532e+10 2022-06-09 08:28:53
# 3664           5.085246e+10            4.317873e+10 2022-06-09 18:02:07
# 3665           5.085246e+10            4.317873e+10 2022-06-09 18:02:07
# 6342           5.089406e+10            4.328120e+10 2022-06-16 06:42:03
# 8033           5.084671e+10            4.429685e+10 2022-06-19 20:58:19
# 8034           5.084671e+10            4.429685e+10 2022-06-19 20:58:19
#
#                        T1                   T2                   T3
# 1074  2022-06-03 11:48:46  2022-06-03 11:50:28  2022-06-03 11:54:26
# 1623  2022-06-04 16:12:39  2022-06-04 16:15:47  2022-06-04 16:21:24
# 2074  2022-06-05 14:14:29  2022-06-05 14:14:35  2022-06-05 14:25:39
# 2698  2022-06-07 10:41:41  2022-06-07 10:43:51  2022-06-07 10:49:34
# 3425  2022-06-09 08:30:46  2022-06-09 08:32:04  2022-06-09 08:41:35
# 3664  2022-06-09 18:04:36  2022-06-09 18:06:03  2022-06-09 18:21:50
# 3665  2022-06-09 18:04:35  2022-06-09 18:05:29  2022-06-09 18:21:11
# 6342  2022-06-16 06:45:27  2022-06-16 06:48:31  2022-06-16 06:51:30
# 8033  2022-06-19 21:00:15  2022-06-19 21:01:39  2022-06-19 21:04:31
# 8034  2022-06-19 21:00:33  2022-06-19 21:02:12  2022-06-19 21:04:45

# %%
intervb_df =  pd.concat([intervb1P003_subset, intervb2P003_subset])
intervb_df.head(5)
# Out:
#       Mission ID  Latitude permanence  Longitude permanence  \
# 206  20222490200            5081396.0              425942.0
# 316  20222500029          508258313.0             4378717.0
# 317  20222500029            5081887.0              440311.0
# 474  20222500165             508523.0              435988.0
# 988  20222510199            5083571.0              434793.0
#
#      Latitude intervention  Longitude intervention                  T0  \
# 206              5083808.0                430484.0 2022-09-06 22:31:42
# 316               508248.0                438185.0 2022-09-07 04:36:15
# 317               508248.0                438185.0 2022-09-07 04:36:15
# 474              5083848.0                444441.0 2022-09-07 14:32:13
# 988              5084948.0                432034.0 2022-09-08 15:40:50
#
#                       T1                   T2                   T3
# 206  2022-09-06 18:35:43  2022-09-06 18:38:18  2022-09-06 18:44:39
# 316  2022-09-07 00:38:49  2022-09-07 00:41:59  2022-09-07 00:42:25
# 317  2022-09-07 00:38:50  2022-09-07 00:41:36  2022-09-07 00:44:59
# 474  2022-09-07 10:35:15  2022-09-07 10:38:37  2022-09-07 10:49:43
# 988  2022-09-08 11:44:34  2022-09-08 11:47:11  2022-09-08 11:52:58

# %%
#Keep only cardiac arrest
i = interv1[interv1['EventType Trip'] != ('P003 - Cardiac arrest')].index
interv1P003 = interv1.drop(i)
i = interv2[interv2['EventType Trip'] != ('P003 - Cardiac arrest')].index
interv2P003 = interv2.drop(i)
i = interv3[interv3['EventType Trip'] != ('P003 - Cardiac arrest')].index
interv3P003 = interv3.drop(i)

print(interv1P003['EventType Trip'].head(5))
print(interv2P003['EventType Trip'].head(5))
print(interv3P003['EventType Trip'].head(5))
# Out:
# 42     P003 - Cardiac arrest
# 87     P003 - Cardiac arrest
# 88     P003 - Cardiac arrest
# 207    P003 - Cardiac arrest
# 208    P003 - Cardiac arrest
# Name: EventType Trip, dtype: object
# 177    P003 - Cardiac arrest
# 178    P003 - Cardiac arrest
# 298    P003 - Cardiac arrest
# 362    P003 - Cardiac arrest
# 427    P003 - Cardiac arrest
# Name: EventType Trip, dtype: object
# 27     P003 - Cardiac arrest
# 150    P003 - Cardiac arrest
# 151    P003 - Cardiac arrest
# 152    P003 - Cardiac arrest
# 176    P003 - Cardiac arrest
# Name: EventType Trip, dtype: object

# %%
interv1P003_subset= interv1P003[['Mission ID','Latitude permanence', 'Longitude permanence','Latitude intervention', 'Longitude intervention','T0', 'T1', 'T2', 'T3']]
print(interv1P003_subset.head())
interv2P003_subset= interv2P003[['Mission ID','Latitude permanence', 'Longitude permanence','Latitude intervention', 'Longitude intervention','T0', 'T1', 'T2', 'T3']]
print(interv2P003_subset.head())
interv3P003_subset= interv3P003[['Mission ID','Latitude permanence', 'Longitude permanence','Latitude intervention', 'Longitude intervention','T0', 'T1', 'T2', 'T3']]
print(interv3P003_subset.head())
# Out:
#       Mission ID  Latitude permanence  Longitude permanence  \
# 42   10221520047             51.16013               4.99975
# 87   10221520095             51.31287               4.32425
# 88   10221520095             51.22249               4.43629
# 207  10221520224             51.22249               4.43629
# 208  10221520224             51.25783               4.45277
#
#      Latitude intervention  Longitude intervention                T0  \
# 42                51.20685                 5.13662  01JUN22:06:45:53
# 87                51.24848                 4.43869  01JUN22:09:28:15
# 88                51.24848                 4.43869  01JUN22:09:28:15
# 207               51.28273                 4.42134  01JUN22:15:11:15
# 208               51.28273                 4.42134  01JUN22:15:11:15
#
#                    T1                       T2                       T3
# 42   01JUN22:06:48:30  2022-06-01 06:52:06.354  2022-06-01 07:04:46.095
# 87   01JUN22:09:29:42  2022-06-01 09:30:28.285  2022-06-01 09:32:29.322
# 88   01JUN22:09:29:44  2022-06-01 09:35:10.792  2022-06-01 09:40:51.753
# 207  01JUN22:15:12:22  2022-06-01 15:14:47.332  2022-06-01 15:24:40.674
# 208  01JUN22:15:12:22  2022-06-01 15:17:56.103  2022-06-01 15:47:52.170
#       Mission ID  Latitude permanence  Longitude permanence  \
# 177  50221920329             50.69450               4.03272
# 178  50221920329             50.58235               4.07888
# 298  50221920517             50.39143               4.42896
# 362  50221920590             50.60684               4.13593
# 427  50221930055             50.41262               4.37692
#
#      Latitude intervention  Longitude intervention                T0  \
# 177               50.69656                 4.03820  11JUL22:15:26:25
# 178               50.69656                 4.03820  11JUL22:15:26:25
# 298               50.34275                 4.47152  11JUL22:20:24:17
# 362               50.59626                 4.15701  11JUL22:23:04:40
# 427               50.40064                 4.39426  12JUL22:05:01:38
#
#                    T1                       T2                       T3
# 177  11JUL22:15:27:59  2022-07-11 15:29:00.228  2022-07-11 15:30:51.737
# 178  11JUL22:15:28:00  2022-07-11 15:35:35.180  2022-07-11 16:18:51.681
# 298  11JUL22:20:27:55  2022-07-11 20:30:07.392  2022-07-11 20:38:11.657
# 362  11JUL22:23:07:04  2022-07-11 23:08:28.349  2022-07-11 23:16:38.583
# 427  12JUL22:05:03:29  2022-07-12 05:06:14.093  2022-07-12 05:12:31.044
#       Mission ID  Latitude permanence  Longitude permanence  \
# 27   60230050040            50.702841              5.652668
# 150  60230050157            50.746210              2.822500
# 151  60230050157            50.781230              3.044290
# 152  60230050157            50.866100              2.895650
# 176  60230050178            50.592003              5.540315
#
#      Latitude intervention  Longitude intervention                T0  \
# 27                50.73437                 5.67101  05JAN23:06:44:32
# 150               50.74748                 2.93860  05JAN23:13:35:10
# 151               50.74748                 2.93860  05JAN23:13:35:10
# 152               50.74748                 2.93860  05JAN23:13:35:10
# 176               50.60025                 5.53550  05JAN23:14:39:31
#
#                    T1                       T2                       T3
# 27   05JAN23:06:46:53  2023-01-05 06:49:28.847  2023-01-05 06:53:16.632
# 150  05JAN23:13:41:23  2023-01-05 13:44:23.433  2023-01-05 13:54:13.274
# 151  05JAN23:13:37:40                     None                     None
# 152  05JAN23:13:37:40  2023-01-05 13:40:00.532  2023-01-05 13:52:22.298
# 176  05JAN23:14:41:05  2023-01-05 14:42:22.865  2023-01-05 15:34:56.735

# %%
from datetime import datetime, timedelta, date

def time_interv2(date_string):
        try:
            date_value=datetime.strptime(date_string, "%d%b%y:%H:%M:%S")
        except:
            date_value=date(1, 1, 1)#Define default value to remove, other function didn't work
        return date_value 

def time_interv3(date_string):
    try:
        date_str,other = date_string.split(".")
        date_value = datetime.strptime(date_str, "%Y-%m-%d %H:%M:%S")
    except:
          date_value=date(1, 1, 1)#Define default value to remove, other function didn't work
    return date_value


t_lst = ['T0','T1']
for t in (t_lst):
    interv1P003_subset[t]=interv1P003_subset.apply(lambda x: time_interv2(x[t]), axis=1)
    i1 = interv1P003_subset[interv1P003_subset[t] == date(1, 1, 1)].index
    interv1P003_subset = interv1P003_subset.drop(i1)
    interv2P003_subset[t]=interv2P003_subset.apply(lambda x: time_interv2(x[t]), axis=1)
    i2 = interv2P003_subset[interv2P003_subset[t] == date(1, 1, 1)].index
    interv2P003_subset = interv2P003_subset.drop(i2)   
    interv3P003_subset[t]=interv3P003_subset.apply(lambda x: time_interv2(x[t]), axis=1)
    i2 = interv3P003_subset[interv3P003_subset[t] == date(1, 1, 1)].index
    interv3P003_subset = interv3P003_subset.drop(i2)  

t_lst2 = ['T2','T3']
for t in (t_lst2):
    interv1P003_subset[t]=interv1P003_subset.apply(lambda x: time_interv3(x[t]), axis=1)
    i1 = interv1P003_subset[interv1P003_subset[t] == date(1, 1, 1)].index
    interv1P003_subset = interv1P003_subset.drop(i1)
    interv2P003_subset[t]=interv2P003_subset.apply(lambda x: time_interv3(x[t]), axis=1)
    i2 = interv2P003_subset[interv2P003_subset[t] == date(1, 1, 1)].index
    interv2P003_subset = interv2P003_subset.drop(i2)   
    interv3P003_subset[t]=interv3P003_subset.apply(lambda x: time_interv3(x[t]), axis=1)
    i2 = interv3P003_subset[interv3P003_subset[t] == date(1, 1, 1)].index
    interv3P003_subset = interv3P003_subset.drop(i2)  
 
print(interv1P003_subset.head(5))
print(interv2P003_subset.head(5))
print(interv3P003_subset.head(5))
# Out:
# C:\Users\Ramy\AppData\Local\Temp\ipykernel_15440\3764523392.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interv1P003_subset[t]=interv1P003_subset.apply(lambda x: time_interv2(x[t]), axis=1)
# C:\Users\Ramy\AppData\Local\Temp\ipykernel_15440\3764523392.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interv2P003_subset[t]=interv2P003_subset.apply(lambda x: time_interv2(x[t]), axis=1)
# C:\Users\Ramy\AppData\Local\Temp\ipykernel_15440\3764523392.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interv3P003_subset[t]=interv3P003_subset.apply(lambda x: time_interv2(x[t]), axis=1)
#       Mission ID  Latitude permanence  Longitude permanence  \
# 42   10221520047             51.16013               4.99975
# 87   10221520095             51.31287               4.32425
# 88   10221520095             51.22249               4.43629
# 207  10221520224             51.22249               4.43629
# 208  10221520224             51.25783               4.45277
#
#      Latitude intervention  Longitude intervention                  T0  \
# 42                51.20685                 5.13662 2022-06-01 06:45:53
# 87                51.24848                 4.43869 2022-06-01 09:28:15
# 88                51.24848                 4.43869 2022-06-01 09:28:15
# 207               51.28273                 4.42134 2022-06-01 15:11:15
# 208               51.28273                 4.42134 2022-06-01 15:11:15
#
#                      T1                   T2                   T3
# 42  2022-06-01 06:48:30  2022-06-01 06:52:06  2022-06-01 07:04:46
# 87  2022-06-01 09:29:42  2022-06-01 09:30:28  2022-06-01 09:32:29
# 88  2022-06-01 09:29:44  2022-06-01 09:35:10  2022-06-01 09:40:51
# 207 2022-06-01 15:12:22  2022-06-01 15:14:47  2022-06-01 15:24:40
# 208 2022-06-01 15:12:22  2022-06-01 15:17:56  2022-06-01 15:47:52
#       Mission ID  Latitude permanence  Longitude permanence  \
# 177  50221920329             50.69450               4.03272
# 178  50221920329             50.58235               4.07888
# 298  50221920517             50.39143               4.42896
# 362  50221920590             50.60684               4.13593
# 427  50221930055             50.41262               4.37692
#
#      Latitude intervention  Longitude intervention                  T0  \
# 177               50.69656                 4.03820 2022-07-11 15:26:25
# 178               50.69656                 4.03820 2022-07-11 15:26:25
# 298               50.34275                 4.47152 2022-07-11 20:24:17
# 362               50.59626                 4.15701 2022-07-11 23:04:40
# 427               50.40064                 4.39426 2022-07-12 05:01:38
#
#                      T1                   T2                   T3
# 177 2022-07-11 15:27:59  2022-07-11 15:29:00  2022-07-11 15:30:51
# 178 2022-07-11 15:28:00  2022-07-11 15:35:35  2022-07-11 16:18:51
# 298 2022-07-11 20:27:55  2022-07-11 20:30:07  2022-07-11 20:38:11
# 362 2022-07-11 23:07:04  2022-07-11 23:08:28  2022-07-11 23:16:38
# 427 2022-07-12 05:03:29  2022-07-12 05:06:14  2022-07-12 05:12:31
#       Mission ID  Latitude permanence  Longitude permanence  \
# 27   60230050040            50.702841              5.652668
# 150  60230050157            50.746210              2.822500
# 152  60230050157            50.866100              2.895650
# 176  60230050178            50.592003              5.540315
# 177  60230050178            50.573250              5.567560
#
#      Latitude intervention  Longitude intervention                  T0  \
# 27                50.73437                 5.67101 2023-01-05 06:44:32
# 150               50.74748                 2.93860 2023-01-05 13:35:10
# 152               50.74748                 2.93860 2023-01-05 13:35:10
# 176               50.60025                 5.53550 2023-01-05 14:39:31
# 177               50.60025                 5.53550 2023-01-05 14:39:31
#
#                      T1                   T2                   T3
# 27  2023-01-05 06:46:53  2023-01-05 06:49:28  2023-01-05 06:53:16
# 150 2023-01-05 13:41:23  2023-01-05 13:44:23  2023-01-05 13:54:13
# 152 2023-01-05 13:37:40  2023-01-05 13:40:00  2023-01-05 13:52:22
# 176 2023-01-05 14:41:05  2023-01-05 14:42:22  2023-01-05 15:34:56
# 177 2023-01-05 14:41:05  2023-01-05 14:42:32  2023-01-05 15:34:54

# %%
interv_df =  pd.concat([interv1P003_subset, interv2P003_subset, interv2P003_subset])
interv_df.head(5)
# Out:
#       Mission ID  Latitude permanence  Longitude permanence  \
# 42   10221520047             51.16013               4.99975
# 87   10221520095             51.31287               4.32425
# 88   10221520095             51.22249               4.43629
# 207  10221520224             51.22249               4.43629
# 208  10221520224             51.25783               4.45277
#
#      Latitude intervention  Longitude intervention                  T0  \
# 42                51.20685                 5.13662 2022-06-01 06:45:53
# 87                51.24848                 4.43869 2022-06-01 09:28:15
# 88                51.24848                 4.43869 2022-06-01 09:28:15
# 207               51.28273                 4.42134 2022-06-01 15:11:15
# 208               51.28273                 4.42134 2022-06-01 15:11:15
#
#                      T1                   T2                   T3
# 42  2022-06-01 06:48:30  2022-06-01 06:52:06  2022-06-01 07:04:46
# 87  2022-06-01 09:29:42  2022-06-01 09:30:28  2022-06-01 09:32:29
# 88  2022-06-01 09:29:44  2022-06-01 09:35:10  2022-06-01 09:40:51
# 207 2022-06-01 15:12:22  2022-06-01 15:14:47  2022-06-01 15:24:40
# 208 2022-06-01 15:12:22  2022-06-01 15:17:56  2022-06-01 15:47:52

# %%
intervALL_df =  pd.concat([interv_df, intervb_df])
intervALL_df.head(5)
# Out:
#       Mission ID  Latitude permanence  Longitude permanence  \
# 42   10221520047             51.16013               4.99975
# 87   10221520095             51.31287               4.32425
# 88   10221520095             51.22249               4.43629
# 207  10221520224             51.22249               4.43629
# 208  10221520224             51.25783               4.45277
#
#      Latitude intervention  Longitude intervention                  T0  \
# 42                51.20685                 5.13662 2022-06-01 06:45:53
# 87                51.24848                 4.43869 2022-06-01 09:28:15
# 88                51.24848                 4.43869 2022-06-01 09:28:15
# 207               51.28273                 4.42134 2022-06-01 15:11:15
# 208               51.28273                 4.42134 2022-06-01 15:11:15
#
#                       T1                   T2                   T3
# 42   2022-06-01 06:48:30  2022-06-01 06:52:06  2022-06-01 07:04:46
# 87   2022-06-01 09:29:42  2022-06-01 09:30:28  2022-06-01 09:32:29
# 88   2022-06-01 09:29:44  2022-06-01 09:35:10  2022-06-01 09:40:51
# 207  2022-06-01 15:12:22  2022-06-01 15:14:47  2022-06-01 15:24:40
# 208  2022-06-01 15:12:22  2022-06-01 15:17:56  2022-06-01 15:47:52

# %%
#intervALL_df['Arrival time in sec'] = intervALL_df['T3'] - intervALL_df['T0']
# intervALL_df['Arrival time in sec'].head(5)
# intervALL_df['Arrival duration']  = intervALL_df['T3'] - intervALL_df['T0']
# interventionALL_df['Arrival Time'].head(5)
def arrival_duration(date1,date2):
    duration = date2 - date1
    duration_sec = duration.total_seconds()
    return duration_sec

intervALL_df['Arrival duration'] = intervALL_df.apply( lambda x : arrival_duration(x['T0'],x['T3']), axis=1)
intervALL_df['Arrival duration'].head(5)
# Out:
# 42     1133.0
# 87      254.0
# 88      756.0
# 207     805.0
# 208    2197.0
# Name: Arrival duration, dtype: float64

# %%
# postal_codes_subset.to_csv('postal_codes.csv', index=False)
aed_subset.to_csv('aed.csv', index=False)
ambulances_subset.to_csv('ambulances.csv', index=False)
intervb_df.to_csv('Interventions_BXL.csv', index=False)
interv_df.to_csv('Interventions_NOTBXL.csv', index=False)
intervALL_df.to_csv('Interventions_ALL.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 # postal_codes_subset.to_csv('postal_codes.csv', index=False)
# ----> 2 aed_subset.to_csv('aed.csv', index=False)
#       3 ambulances_subset.to_csv('ambulances.csv', index=False)
#       4 intervb_df.to_csv('Interventions_BXL.csv', index=False)
#
# NameError: name 'aed_subset' is not defined

# %%
intervb_df.to_csv('Interventions_BXL.csv', index=False)
interv_df.to_csv('Interventions_NOTBXL.csv', index=False)
intervALL_df.to_csv('Interventions_ALL.csv', index=False)
