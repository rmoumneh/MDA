# %%
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

root_dir = '../../data/'

# %%
pd.set_option('display.max_columns', None)

# %%
df = root_dir + 'raw/interventions/cad9.parquet.gzip'

df = pq.read_table(df)
df = df.to_pandas()
df.head()
# Out:
#   province   Mission ID                 Service Name  Latitude permanence  \
# 0      VBR  21221520003             MV HVP VILV West            50.925277
# 1      VBR  21221520004             MV HVP HALL West            50.743200
# 2      VBR  21221520007             MV HVP VILV West            50.925277
# 3      VBR  21221520007   HV UR VILV AZ Jan Portaels            50.926869
# 4      VBR  21221520008  BB BRUX Hôpital Militair KA            50.905331
#
#    Longitude permanence Permanence short name Permanence long name  \
# 0              4.423057             AVVILV01A       ZW VILVOORDE 1
# 1              4.241053             AVHALL02A           ZW HALLE 2
# 2              4.423057             AVVILV01A       ZW VILVOORDE 1
# 3              4.420968             UVVILV01A        MUG VILVOORDE
# 4              4.387662             ABBRUX13A           AMB HMB 13
#
#   Vector Type                                  EventType Trip  \
# ...

# %%
intervent

# %%
from sklearn.cluster import DBSCAN
import numpy as np

# Assuming you have a list of (latitude, longitude) tuples
data_points = np.array([
    [lat1, lon1],
    [lat2, lon2],
    # ... (more points)
])

# Define the epsilon (radius) and minimum samples for DBSCAN
epsilon = 0.01  # Approx 1 km (adjust based on your needs)
min_samples = 5  # Minimum number of points to form a cluster

# Perform DBSCAN clustering
db = DBSCAN(eps=epsilon, min_samples=min_samples, metric='haversine').fit(np.radians(data_points))

# Extract cluster labels
labels = db.labels_
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.cluster import DBSCAN
#       2 import numpy as np
#       4 # Assuming you have a list of (latitude, longitude) tuples
#
# ModuleNotFoundError: No module named 'sklearn'
